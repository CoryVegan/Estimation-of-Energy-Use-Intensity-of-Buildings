# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("together.csv",encoding='latin-1')

# %%
structure = df[['STRUCTURE_CLASS','EUI']]
structure = structure[structure['STRUCTURE_CLASS'].notnull()]
structure
# Out:
#     STRUCTURE_CLASS      EUI
# 0                 B      5.1
# 1                 A     98.2
# 2                 B     69.0
# 3                 R     63.0
# 4                 C     51.4
# 6                 A     26.2
# 7                 B     72.1
# 9                 A     61.4
# 10                C     52.9
# 12                B     85.5
# 14                B     84.6
# 16                C     78.6
# 17                R     46.1
# 20                C     59.5
# 21                B     86.3
# 22                R     86.1
# 23                C     77.5
# 24                B     85.8
# 25                A     80.2
# 26                A     79.7
# 27                A     82.5
# 29                B     85.1
# 30                B    120.3
# 35                A     61.0
# 36                A     79.2
# 37                A     61.7
# 39                B      3.4
# 41                A     74.9
# 42                R     62.6
# 43                A     75.4
# ..              ...      ...
# 706               C     59.9
# 707               B    155.3
# 708               B    192.7
# 709               C      2.1
# 710               C     86.3
# 711               C     33.9
# 713               C    134.7
# 714               C    385.2
# 715               C     90.7
# 717               B    220.0
# 718               B     51.9
# 719               B     62.8
# 720               B      1.3
# 722               C     27.8
# 724               B     80.0
# 725               C    117.5
# 726               C     90.8
# 727               C    321.5
# 729               B    113.5
# 730               B     86.3
# 731               C     95.1
# 732               C     59.9
# 734               B    174.9
# 735               B    197.0
# 736               C    355.8
# 737               C     81.7
# 740               B    175.2
# 742               C  21666.5
# 743               C     78.2
# 744               C    200.0
#
# [603 rows x 2 columns]

# %%
structure.sort_values(by='EUI',ascending=False)
# Out:
#     STRUCTURE_CLASS      EUI
# 168               C  63284.2
# 702               C  31779.9
# 742               C  21666.5
# 271               C   2897.8
# 214               B   1824.0
# 460               D    760.1
# 101               C    559.7
# 141               A    486.9
# 124               B    484.0
# 122               A    435.5
# 313               C    426.3
# 254               B    413.9
# 465               C    389.0
# 714               C    385.2
# 232               C    375.3
# 309               C    365.2
# 736               C    355.8
# 304               B    351.3
# 639               C    346.9
# 248               C    323.6
# 727               C    321.5
# 345               B    314.3
# 428               C    308.4
# 192               C    305.3
# 62                B    300.1
# 696               B    296.7
# 519               B    292.4
# 498               C    291.6
# 553               B    287.4
# 663               B    286.7
# ..              ...      ...
# 652               C      9.4
# 504               C      9.3
# 237               D      8.5
# 497               D      8.4
# 604               C      8.4
# 655               C      7.3
# 515               C      7.3
# 429               R      7.1
# 218               C      6.6
# 451               C      6.2
# 225               C      6.2
# 495               C      6.0
# 508               C      5.8
# 120               C      5.7
# 372               B      5.4
# 328               B      5.4
# 0                 B      5.1
# 128               B      4.7
# 260               C      4.5
# 39                B      3.4
# 136               C      2.1
# 709               C      2.1
# 154               B      1.8
# 116               C      1.7
# 145               R      1.4
# 720               B      1.3
# 303               B      0.9
# 290               C      0.5
# 140               C      0.3
# 609               B      0.0
#
# [603 rows x 2 columns]

# %%
to_drop = []
for key,value in structure.iterrows():
    if value[1]>800:
        to_drop.append(key)
structure = structure.drop(to_drop)
structure.sort_values(by='EUI', ascending=False)
# Out:
#     STRUCTURE_CLASS    EUI
# 460               D  760.1
# 101               C  559.7
# 141               A  486.9
# 124               B  484.0
# 122               A  435.5
# 313               C  426.3
# 254               B  413.9
# 465               C  389.0
# 714               C  385.2
# 232               C  375.3
# 309               C  365.2
# 736               C  355.8
# 304               B  351.3
# 639               C  346.9
# 248               C  323.6
# 727               C  321.5
# 345               B  314.3
# 428               C  308.4
# 192               C  305.3
# 62                B  300.1
# 696               B  296.7
# 519               B  292.4
# 498               C  291.6
# 553               B  287.4
# 663               B  286.7
# 307               A  286.6
# 614               C  274.1
# 562               C  272.9
# 301               C  272.2
# 699               C  271.5
# ..              ...    ...
# 652               C    9.4
# 504               C    9.3
# 237               D    8.5
# 604               C    8.4
# 497               D    8.4
# 515               C    7.3
# 655               C    7.3
# 429               R    7.1
# 218               C    6.6
# 451               C    6.2
# 225               C    6.2
# 495               C    6.0
# 508               C    5.8
# 120               C    5.7
# 328               B    5.4
# 372               B    5.4
# 0                 B    5.1
# 128               B    4.7
# 260               C    4.5
# 39                B    3.4
# 709               C    2.1
# 136               C    2.1
# 154               B    1.8
# 116               C    1.7
# 145               R    1.4
# 720               B    1.3
# 303               B    0.9
# 290               C    0.5
# 140               C    0.3
# 609               B    0.0
#
# [598 rows x 2 columns]

# %%
structure_copy = structure.copy()
structure_copy["count"] = np.ones(len(structure),dtype=int)
count = structure_copy.groupby("STRUCTURE_CLASS").sum()
count
# Out:
#                      EUI  count
# STRUCTURE_CLASS
# A                 4998.0     54
# B                11200.6    110
# C                30468.2    355
# D                 2177.5     30
# R                 3957.0     49

# %%
count["ave_eui"] = count["EUI"] / count["count"]
count = count.sort_values(by='ave_eui', ascending=False).iloc[:,[2]]
count
# Out:
#                     ave_eui
# STRUCTURE_CLASS
# B                101.823636
# A                 92.555556
# C                 85.825915
# R                 80.755102
# D                 72.583333

# %%
x = ["A","B","C","D","E","R"]
y = ["Struct Steel","Reinforced Concrete","Brick/Concrete","Wood/Frame","Metal","Residential"]
dict1 = dict(zip(x, y))

# %%
tmp = count.copy()
tmp.index = [dict1[i] for i in list(count.index)]
tmp
# Out:
#                         ave_eui
# Reinforced Concrete  101.823636
# Struct Steel          92.555556
# Brick/Concrete        85.825915
# Residential           80.755102
# Wood/Frame            72.583333

# %%
tmp.plot(kind='bar',figsize=(8,5),title="How structure classes affect average EUI", fontsize=13)

# %%
df_HDD
# Out:
#    Month starting   HDD  % Estimated
# 0        2015/4/1   515         0.20
# 1        2015/5/1   189         0.10
# 2        2015/6/1   126         0.30
# 3        2015/7/1     7         0.30
# 4        2015/8/1     2         0.20
# 5        2015/9/1    45         0.20
# 6       2015/10/1   354         0.30
# 7       2015/11/1   498         0.10
# 8       2015/12/1   626         0.03
# 9        2016/1/1  1015         0.20
# 10       2016/2/1   883         0.10
# 11       2016/3/1   709         0.10
# 12       2016/4/1   551         0.20
# 13       2016/5/1   274         0.10
# 14       2016/6/1    47         0.20
# 15       2016/7/1    11         0.20
# 16       2016/8/1     1         0.20
# 17       2016/9/1    64         0.20
# 18      2016/10/1   322         0.20
# 19      2016/11/1   573         0.07
# 20      2016/12/1   920         0.10
# 21       2017/1/1   922         0.03
# 22       2017/2/1   805         0.10
# 23       2017/3/1   959         0.03
# 24       2017/4/1   446         0.10
# 25       2017/5/1   327         0.03
# 26       2017/6/1    70         0.10
# 27       2017/7/1    20         0.20
# 28       2017/8/1    12         0.10
# 29       2017/9/1    60         0.10
# 30      2017/10/1   170         0.03
# 31      2017/11/1   633         0.10
# 32      2017/12/1  1074         0.06
# 33       2018/1/1  1120         0.30
# 34       2018/2/1   752         0.00
# 35       2018/3/1   878         0.20

# %%
df_HDD=pd.read_csv("KBOS_HDD_65F-3.csv",encoding='latin-1')
missing_HDD = [1203,1282,980]

hdd_2015 = sum(missing_HDD) + sum(df_HDD['HDD'][0:9])
hdd_2016 = sum(df_HDD['HDD'][9:21])
hdd_2017 = sum(df_HDD['HDD'][21:33])

# %%
df_CDD=pd.read_csv("KBOS_CDD_65F-3.csv",encoding='latin-1')
df_CDD
# Out:
#    Month starting  CDD  % Estimated
# 0        2015/4/1    2         0.20
# 1        2015/5/1   86         0.10
# 2        2015/6/1   95         0.30
# 3        2015/7/1  272         0.30
# 4        2015/8/1  276         0.20
# 5        2015/9/1  164         0.20
# 6       2015/10/1   11         0.30
# 7       2015/11/1    7         0.10
# 8       2015/12/1    1         0.03
# 9        2016/1/1    0         0.20
# 10       2016/2/1    0         0.10
# 11       2016/3/1    3         0.10
# 12       2016/4/1    4         0.20
# 13       2016/5/1   51         0.10
# 14       2016/6/1  134         0.20
# 15       2016/7/1  333         0.20
# 16       2016/8/1  341         0.20
# 17       2016/9/1  126         0.20
# 18      2016/10/1   13         0.20
# 19      2016/11/1    0         0.07
# 20      2016/12/1    0         0.10
# 21       2017/1/1    0         0.03
# 22       2017/2/1    1         0.10
# 23       2017/3/1    0         0.03
# 24       2017/4/1   32         0.10
# 25       2017/5/1   50         0.03
# 26       2017/6/1  194         0.10
# 27       2017/7/1  238         0.20
# 28       2017/8/1  212         0.10
# 29       2017/9/1  105         0.10
# 30      2017/10/1   55         0.03
# 31      2017/11/1    3         0.10
# 32      2017/12/1    0         0.06
# 33       2018/1/1    0         0.30
# 34       2018/2/1    2         0.00
# 35       2018/3/1    0         0.20

# %%
cdd_2015 = sum(df_CDD['CDD'][0:9]) + sum([0,0,0])
cdd_2016 = sum(df_CDD['CDD'][9:21])
cdd_2017 = sum(df_CDD['CDD'][21:33])

# %%
import matplotlib.pyplot as plt
import numpy as np
x_axis = ['2015','2016','2017']
x = range(len(x_axis))
y_cdd = [cdd_2015,cdd_2016,cdd_2017]
y_hdd = [hdd_2015,hdd_2016,hdd_2017]
plt.plot(x, y_cdd, 'bo-')
plt.xticks(x, x_axis, rotation=45)
plt.margins(0.08)
plt.subplots_adjust(bottom=0.15)
plt.title('2015-2017 CDD')
plt.ylabel('CDD')
plt.show()

# %%
plt.plot(x, y_hdd, 'ro-')
plt.xticks(x, x_axis, rotation=45)
plt.margins(0.08)
plt.subplots_adjust(bottom=0.15)
plt.title('2015-2017 HDD')
plt.ylabel('HDD')
plt.show()
