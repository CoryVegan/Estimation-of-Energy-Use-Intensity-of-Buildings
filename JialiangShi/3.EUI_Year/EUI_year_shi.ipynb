# %%
import csv
import pandas as pd
import numpy as np
import xlrd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Read and preprocess berdo2017

# %%
berdo2017 = pd.read_csv("berdo2017.csv",encoding='latin-1')
berdo2017_type_eui = berdo2017.loc[:,["Property Type","Site EUI (kBTU/sf)"]]
type_eui_2017 = berdo2017_type_eui[berdo2017_type_eui["Site EUI (kBTU/sf)"]!="Not Available"]
for i in range(len(type_eui_2017)):
    type_eui_2017.iloc[i][1] = float(type_eui_2017.iloc[i][1])

# %% [markdown]
# ### Detect and remove outliers

# %%
to_drop = []
for key,value in type_eui_2017.iterrows():
    if value[1]>800:
        to_drop.append(key)
to_drop.append(1521) #special case.Only one "Other-Utility" with 500+ EUI.
type_eui_2017 = type_eui_2017.drop(to_drop)
type_eui_2017.sort_values(by='Site EUI (kBTU/sf)', ascending=False)
# Out:
#                                    Property Type Site EUI (kBTU/sf)
# 898                          Multifamily Housing              760.1
# 1460                              Police Station              664.5
# 1714                                       Other              639.4
# 1050              Manufacturing/Industrial Plant              626.1
# 275                                   Laboratory              559.7
# 1635                                       Other              547.2
# 439                          Multifamily Housing              520.3
# 426        Hospital (General Medical & Surgical)              486.9
# 365                   Other - Specialty Hospital                484
# 1782                                      Office                472
# 137                                       Office              463.5
# 386                                   Laboratory              451.8
# 1049                              Police Station              440.7
# 346                                   Laboratory              440.6
# 363                                   Laboratory              435.5
# 357                                   Laboratory              432.4
# 371                                   Laboratory              429.3
# 642                               Medical Office              426.3
# 534                          Multifamily Housing              420.3
# 1127                                       Hotel              413.9
# 1726                                       Other              405.8
# 1730                                       Other              401.2
# 935                                  K-12 School                389
# 1689                                  Laboratory              386.6
# 1693  Outpatient Rehabilitation/Physical Therapy              385.2
# 1728                                       Other                382
# 402                                   Laboratory              381.8
# 1136                                      Office              375.3
# 193                                   Laboratory                371
# 623                               Medical Office              365.2
# ...                                          ...                ...
# 751                                        Other                5.4
# 1557                                     Parking                5.2
# 5                                        Parking                5.1
# 377                                      Parking                4.7
# 615                           Mixed Use Property                4.5
# 1652                          College/University                4.3
# 516                                 Retail Store                4.3
# 1747                                     Parking                3.6
# 147                          Multifamily Housing                3.5
# 1480                          Mixed Use Property                3.4
# 1156                                     Parking                3.4
# 104                                      Parking                3.4
# 781                           Other - Recreation                3.2
# 1026                                      Office                  3
# 1390                         Multifamily Housing                2.8
# 310                                       Office                2.4
# 404                          Multifamily Housing                2.1
# 1674                         Multifamily Housing                2.1
# 730                           Mixed Use Property                  2
# 462                                        Other                1.8
# 323                          Multifamily Housing                1.7
# 1409                       Self-Storage Facility                1.5
# 447                           College/University                1.4
# 1718                                       Hotel                1.3
# 637                                      Parking                0.9
# 950                   Non-Refrigerated Warehouse                0.5
# 1650                         Multifamily Housing                0.3
# 1758                             Other - Stadium                0.3
# 422                           College/University                0.3
# 1388                                      Office                  0
#
# [1652 rows x 2 columns]

# %% [markdown]
# ### Group by Property Type, and sum up EUI

# %%
eui2017 = type_eui_2017.groupby("Property Type", as_index = False).sum()
eui2017.columns = ['Property_Type','EUI']
eui2017
# Out:
#                                        Property_Type      EUI
# 0                                    Adult Education    121.2
# 1                         Ambulatory Surgical Center    205.9
# 2                                           Aquarium     76.8
# 3                              Automobile Dealership    134.5
# 4                                           Barracks     54.3
# 5                                 College/University   7124.7
# 6                                         Courthouse     75.5
# 7                                Distribution Center    313.2
# 8                                      Enclosed Mall     19.8
# 9                               Energy/Power Station    103.4
# 10                                  Financial Office    674.7
# 11                                      Fire Station   4462.8
# 12                    Fitness Center/Health Club/Gym   1167.8
# 13                                      Food Service    101.6
# 14             Hospital (General Medical & Surgical)   3574.5
# 15                                             Hotel   4769.5
# 16                                  Ice/Curling Rink    108.9
# 17                                      Indoor Arena    601.3
# 18                                       K-12 School   9220.8
# 19                                        Laboratory   9907.1
# 20                                           Library   2284.9
# 21                                  Lifestyle Center     45.0
# 22                    Manufacturing/Industrial Plant   1807.5
# 23                                    Medical Office   4109.8
# 24                                Mixed Use Property   3610.0
# 25                                     Movie Theater     89.4
# 26                               Multifamily Housing  40084.2
# 27                                            Museum    959.4
# 28                        Non-Refrigerated Warehouse    596.0
# 29                                            Office  23680.0
# ..                                               ...      ...
# 32             Other - Entertainment/Public Assembly    236.3
# 33                       Other - Lodging/Residential   1524.3
# 34                                      Other - Mall    168.8
# 35                           Other - Public Services    151.5
# 36                                Other - Recreation    652.2
# 37                                  Other - Services    336.8
# 38                        Other - Specialty Hospital   1018.5
# 39                                   Other - Stadium    435.9
# 40        Outpatient Rehabilitation/Physical Therapy    435.8
# 41                                           Parking    802.0
# 42                                   Performing Arts    792.6
# 43                                    Police Station   3777.3
# 44                                Pre-school/Daycare    160.9
# 45                            Refrigerated Warehouse     68.9
# 46  Repair Services (Vehicle, Shoe, Locksmith, etc.)   1162.1
# 47                          Residence Hall/Dormitory   2772.7
# 48                         Residential Care Facility     75.0
# 49                                      Retail Store    888.8
# 50                             Self-Storage Facility    389.5
# 51                             Senior Care Community   1726.2
# 52                                Single Family Home     57.5
# 53                               Social/Meeting Hall   1580.4
# 54                                    Stadium (Open)    152.4
# 55                                        Strip Mall    429.5
# 56                         Supermarket/Grocery Store   4198.3
# 57                                     Swimming Pool   1185.6
# 58               Urgent Care/Clinic/Other Outpatient    420.8
# 59                                 Veterinary Office    250.1
# 60                                 Vocational School     77.5
# 61                                  Worship Facility    623.6
#
# [62 rows x 2 columns]

# %% [markdown]
# # Read and preprocess berdo2016

# %%
berdo2016 = pd.read_excel("2016-reported-energy-and-water-metrics.xlsx",encoding='latin-1')
berdo2016_type_eui = berdo2016.loc[:,["Property Type","Site EUI (kBTU/sf)"]]
type_eui_2016 = berdo2016_type_eui[berdo2016_type_eui["Site EUI (kBTU/sf)"]!="Not Available"]
for i in range(len(type_eui_2016)):
    type_eui_2016.iloc[i][1] = float(type_eui_2016.iloc[i][1])

# %% [markdown]
# ### Detect and remove outliers

# %%
type_eui_2016.sort_values(by='Site EUI (kBTU/sf)',ascending=False)
# Out:
#                        Property Type Site EUI (kBTU/sf)
# 693                            Hotel             491452
# 1335                           Hotel             121018
# 1412                  Medical Office             117403
# 1345                  Medical Office            70898.6
# 1424              Mixed Use Property            51766.3
# 1125                           Hotel            50151.6
# 744                 Worship Facility            47878.2
# 1373                Worship Facility            36859.1
# 1448                 Performing Arts            34451.6
# 1215                          Office            27874.2
# 167                           Office            25693.9
# 417            Automobile Dealership            15763.6
# 1440                      Strip Mall            13966.9
# 549                  Other - Utility             5634.3
# 1293             Multifamily Housing             2192.8
# 876                            Other              738.9
# 1358  Manufacturing/Industrial Plant              684.4
# 268              Multifamily Housing              683.1
# 695                            Other              671.2
# 698                            Other                604
# 228              Multifamily Housing              567.9
# 243              Multifamily Housing                549
# 1040                      Laboratory              535.6
# 605                  Other - Utility              526.3
# 878                       Laboratory              517.8
# 1451                      Laboratory              513.2
# 1265                      Laboratory              486.9
# 976                       Restaurant              482.5
# 352                       Laboratory              477.5
# 509       Other - Specialty Hospital              475.6
# ...                              ...                ...
# 1255               Other - Education                5.6
# 1288                         Parking                5.6
# 1219                           Other                5.5
# 175              Multifamily Housing                5.5
# 801                          Parking                4.7
# 1228                      Strip Mall                4.6
# 395                Other - Education                4.3
# 984         Residence Hall/Dormitory                4.2
# 1103                         Parking                4.2
# 643              Multifamily Housing                4.1
# 1205                         Parking                3.9
# 335                            Other                3.8
# 130              Multifamily Housing                3.3
# 689                      K-12 School                2.8
# 1291                    Retail Store                2.5
# 690                            Other                2.3
# 287                            Other                2.2
# 76                             Other                1.9
# 789             Energy/Power Station                1.9
# 683                           Office                1.9
# 1148             Multifamily Housing                1.4
# 344                          Parking                  1
# 719       Non-Refrigerated Warehouse                0.6
# 348                            Other                0.6
# 244                     Retail Store                0.5
# 1098                    Fire Station                0.4
# 381              Multifamily Housing                0.3
# 346                           Office                0.3
# 330                  Other - Stadium                0.3
# 122                           Office                0.1
#
# [1422 rows x 2 columns]

# %%
# Normally, EUI will not be over 800, which can be proved by this
type_eui_2016[type_eui_2016["Property Type"] == "Office"].sort_values(by='Site EUI (kBTU/sf)',ascending=False)
# Out:
#      Property Type Site EUI (kBTU/sf)
# 1215        Office            27874.2
# 167         Office            25693.9
# 271         Office              434.4
# 404         Office              423.2
# 187         Office                348
# 59          Office              278.9
# 626         Office                210
# 172         Office              208.1
# 785         Office              203.8
# 391         Office              186.8
# 35          Office              177.5
# 85          Office              177.2
# 226         Office              176.9
# 625         Office              164.7
# 147         Office                162
# 834         Office              153.4
# 210         Office              152.1
# 854         Office              147.6
# 141         Office              147.4
# 1038        Office              143.4
# 476         Office              141.7
# 123         Office              140.9
# 1389        Office              139.2
# 161         Office              138.9
# 911         Office              138.9
# 1071        Office              137.6
# 530         Office              132.8
# 628         Office              131.9
# 1367        Office                129
# 252         Office              127.1
# ...            ...                ...
# 44          Office                 39
# 31          Office               38.7
# 63          Office               38.1
# 255         Office               37.8
# 1282        Office               37.5
# 991         Office               36.7
# 269         Office               36.6
# 73          Office               36.4
# 1484        Office               35.7
# 184         Office               34.5
# 375         Office               33.9
# 191         Office               33.5
# 107         Office               31.6
# 267         Office                 31
# 1387        Office               30.9
# 522         Office               30.2
# 194         Office                 30
# 281         Office               29.9
# 1267        Office               28.8
# 169         Office               28.1
# 222         Office               27.3
# 261         Office               26.6
# 392         Office               24.1
# 62          Office                 24
# 42          Office               19.4
# 571         Office                 16
# 152         Office               13.2
# 683         Office                1.9
# 346         Office                0.3
# 122         Office                0.1
#
# [287 rows x 2 columns]

# %%
# Normally, EUI will not be over 800, which can be proved by this
type_eui_2016[type_eui_2016["Property Type"] == "Multifamily Housing"].sort_values(by='Site EUI (kBTU/sf)',ascending=False)
# Out:
#             Property Type Site EUI (kBTU/sf)
# 1293  Multifamily Housing             2192.8
# 268   Multifamily Housing              683.1
# 228   Multifamily Housing              567.9
# 243   Multifamily Housing                549
# 1456  Multifamily Housing              250.2
# 52    Multifamily Housing              226.9
# 183   Multifamily Housing              200.3
# 46    Multifamily Housing              193.4
# 1413  Multifamily Housing                182
# 1445  Multifamily Housing              176.3
# 828   Multifamily Housing              171.2
# 1243  Multifamily Housing              155.1
# 1007  Multifamily Housing              147.6
# 1208  Multifamily Housing              144.7
# 1085  Multifamily Housing              141.9
# 1157  Multifamily Housing              141.6
# 1048  Multifamily Housing              141.3
# 478   Multifamily Housing              138.2
# 1278  Multifamily Housing              137.6
# 1408  Multifamily Housing              133.9
# 806   Multifamily Housing              131.9
# 1476  Multifamily Housing              131.7
# 646   Multifamily Housing              130.9
# 1455  Multifamily Housing              130.6
# 306   Multifamily Housing                130
# 387   Multifamily Housing              127.4
# 568   Multifamily Housing              126.1
# 857   Multifamily Housing              124.9
# 1321  Multifamily Housing              124.4
# 802   Multifamily Housing              123.3
# ...                   ...                ...
# 664   Multifamily Housing               22.8
# 132   Multifamily Housing               22.7
# 485   Multifamily Housing               22.7
# 235   Multifamily Housing               22.4
# 1308  Multifamily Housing               21.2
# 1165  Multifamily Housing               20.6
# 644   Multifamily Housing               20.2
# 452   Multifamily Housing               18.6
# 1260  Multifamily Housing               17.2
# 533   Multifamily Housing               16.8
# 1425  Multifamily Housing               16.1
# 737   Multifamily Housing               15.6
# 617   Multifamily Housing               14.8
# 1246  Multifamily Housing               14.2
# 602   Multifamily Housing               14.1
# 872   Multifamily Housing                 12
# 831   Multifamily Housing               11.6
# 1460  Multifamily Housing               11.5
# 325   Multifamily Housing               11.2
# 682   Multifamily Housing               10.5
# 254   Multifamily Housing                9.5
# 595   Multifamily Housing                8.9
# 622   Multifamily Housing                8.6
# 839   Multifamily Housing                8.3
# 526   Multifamily Housing                6.7
# 175   Multifamily Housing                5.5
# 643   Multifamily Housing                4.1
# 130   Multifamily Housing                3.3
# 1148  Multifamily Housing                1.4
# 381   Multifamily Housing                0.3
#
# [334 rows x 2 columns]

# %%
to_drop = []
for key,value in type_eui_2016.iterrows():
    if value[1]>800:
        to_drop.append(key)
type_eui_2016 = type_eui_2016.drop(to_drop)
type_eui_2016.sort_values(by='Site EUI (kBTU/sf)', ascending=False)
# Out:
#                                    Property Type Site EUI (kBTU/sf)
# 876                                        Other              738.9
# 1358              Manufacturing/Industrial Plant              684.4
# 268                          Multifamily Housing              683.1
# 695                                        Other              671.2
# 698                                        Other                604
# 228                          Multifamily Housing              567.9
# 243                          Multifamily Housing                549
# 1040                                  Laboratory              535.6
# 605                              Other - Utility              526.3
# 878                                   Laboratory              517.8
# 1451                                  Laboratory              513.2
# 1265                                  Laboratory              486.9
# 976                                   Restaurant              482.5
# 352                                   Laboratory              477.5
# 509                   Other - Specialty Hospital              475.6
# 696                                        Other              461.2
# 498                                   Laboratory              459.8
# 871                               Police Station              435.2
# 271                                       Office              434.4
# 699                               Medical Office              434.2
# 694                                        Other              429.2
# 404                                       Office              423.2
# 1046                                  Laboratory              419.8
# 1269       Hospital (General Medical & Surgical)              418.2
# 315                               Medical Office              416.7
# 15                     Supermarket/Grocery Store                413
# 339                                   Laboratory              402.2
# 1106                     Other - Public Services              396.9
# 928                                   Laboratory              387.3
# 1176  Outpatient Rehabilitation/Physical Therapy              383.5
# ...                                          ...                ...
# 1288                                     Parking                5.6
# 1255                           Other - Education                5.6
# 175                          Multifamily Housing                5.5
# 1219                                       Other                5.5
# 801                                      Parking                4.7
# 1228                                  Strip Mall                4.6
# 395                            Other - Education                4.3
# 984                     Residence Hall/Dormitory                4.2
# 1103                                     Parking                4.2
# 643                          Multifamily Housing                4.1
# 1205                                     Parking                3.9
# 335                                        Other                3.8
# 130                          Multifamily Housing                3.3
# 689                                  K-12 School                2.8
# 1291                                Retail Store                2.5
# 690                                        Other                2.3
# 287                                        Other                2.2
# 789                         Energy/Power Station                1.9
# 683                                       Office                1.9
# 76                                         Other                1.9
# 1148                         Multifamily Housing                1.4
# 344                                      Parking                  1
# 348                                        Other                0.6
# 719                   Non-Refrigerated Warehouse                0.6
# 244                                 Retail Store                0.5
# 1098                                Fire Station                0.4
# 330                              Other - Stadium                0.3
# 346                                       Office                0.3
# 381                          Multifamily Housing                0.3
# 122                                       Office                0.1
#
# [1407 rows x 2 columns]

# %% [markdown]
# ### Group by Property Type, and sum up EUI

# %%
eui2016 = type_eui_2016.groupby("Property Type", as_index = False).sum()
eui2016.columns = ['Property_Type','EUI']
eui2016
# Out:
#                                        Property_Type       EUI
# 0                                    Adult Education     84.50
# 1                         Ambulatory Surgical Center    205.20
# 2                                 College/University   9238.50
# 3                                         Courthouse     82.50
# 4                                Distribution Center    745.20
# 5                               Energy/Power Station    139.50
# 6                                   Financial Office    891.60
# 7                                       Fire Station   5022.40
# 8                     Fitness Center/Health Club/Gym    774.30
# 9                                       Food Service     82.80
# 10             Hospital (General Medical & Surgical)   3451.10
# 11                                             Hotel   3945.10
# 12                                  Ice/Curling Rink    115.40
# 13                                      Indoor Arena    671.90
# 14                                       K-12 School   8983.90
# 15                                        Laboratory  10772.70
# 16                                           Library   2660.10
# 17                    Manufacturing/Industrial Plant   1576.70
# 18                                    Medical Office   3828.40
# 19                              Mental Health Center    125.59
# 20                                Mixed Use Property   1445.70
# 21                                     Movie Theater     94.50
# 22                               Multifamily Housing  25233.90
# 23                                            Museum    760.60
# 24                        Non-Refrigerated Warehouse    411.40
# 25                                            Office  22848.90
# 26                                             Other   6847.70
# 27                                 Other - Education    760.10
# 28             Other - Entertainment/Public Assembly    509.60
# 29                       Other - Lodging/Residential    860.80
# 30                                      Other - Mall    379.90
# 31                           Other - Public Services    611.50
# 32                                Other - Recreation   2643.40
# 33                                  Other - Services    182.50
# 34                        Other - Specialty Hospital   1156.10
# 35                                   Other - Stadium     98.00
# 36                                   Other - Utility    526.30
# 37        Outpatient Rehabilitation/Physical Therapy    431.60
# 38                                           Parking   2019.70
# 39                                   Performing Arts    622.30
# 40                                    Police Station   3632.90
# 41                                Pre-school/Daycare     36.10
# 42                                        Race Track     37.70
# 43  Repair Services (Vehicle, Shoe, Locksmith, etc.)    860.50
# 44                          Residence Hall/Dormitory   2857.40
# 45                         Residential Care Facility    220.90
# 46                                        Restaurant    510.00
# 47                                      Retail Store   1225.40
# 48                             Self-Storage Facility    187.50
# 49                             Senior Care Community   1229.00
# 50                                Single Family Home     56.40
# 51                               Social/Meeting Hall    379.20
# 52                                    Stadium (Open)    153.80
# 53                             State Office Building    350.30
# 54                                        Strip Mall    213.90
# 55                         Supermarket/Grocery Store   5195.60
# 56               Urgent Care/Clinic/Other Outpatient    387.60
# 57                                 Veterinary Office     82.20
# 58                                 Vocational School     33.10
# 59                                  Worship Facility    523.90

# %% [markdown]
# # Read and preprocess berdo2015

# %%
berdo2015 = pd.read_excel("2015-reported-energy-and-water-metrics.xlsx",encoding='latin-1')
berdo2015_type_eui = berdo2015.loc[:,["Property Type","Site EUI (kBTU/sf)"]]
type_eui_2015 = berdo2015_type_eui[berdo2015_type_eui["Site EUI (kBTU/sf)"]!="Not Available"]
for i in range(len(type_eui_2015)):
    type_eui_2015.iloc[i][1] = float(type_eui_2015.iloc[i][1])

# %% [markdown]
# ### Detect and remove outliers

# %%
type_eui_2015.sort_values(by='Site EUI (kBTU/sf)',ascending=False)
# Out:
#                        Property Type Site EUI (kBTU/sf)
# 160                            Hotel             545557
# 1169     Other - Lodging/Residential             110471
# 43                College/University            73235.1
# 136   Fitness Center/Health Club/Gym            69141.5
# 1287        Residence Hall/Dormitory            60354.8
# 872                           Office            27567.3
# 186                            Hotel            25348.8
# 1140                           Other               3465
# 1115                           Other             3086.3
# 44                College/University             2362.9
# 474              Multifamily Housing             2361.4
# 361                       Laboratory             1329.3
# 633              Multifamily Housing             1199.3
# 1339           Senior Care Community                921
# 413   Manufacturing/Industrial Plant              684.5
# 1154                           Other              619.6
# 412   Manufacturing/Industrial Plant              611.9
# 1152                           Other              603.6
# 1231                         Parking              585.4
# 348                       Laboratory              578.7
# 338                       Laboratory              568.8
# 778              Multifamily Housing            564.715
# 408   Manufacturing/Industrial Plant              543.7
# 349                       Laboratory              527.5
# 345                       Laboratory              487.6
# 1221                 Other - Utility              474.1
# 1215      Other - Specialty Hospital              473.6
# 339                       Laboratory                469
# 341                       Laboratory              455.4
# 372                       Laboratory              435.5
# ...                              ...                ...
# 1234                         Parking                5.4
# 1227                         Parking                  5
# 1160               Other - Education                4.3
# 1237                         Parking                4.2
# 582              Multifamily Housing                3.8
# 500              Multifamily Housing                3.8
# 77              Energy/Power Station                3.7
# 555              Multifamily Housing                2.9
# 1326                    Retail Store                2.9
# 461              Multifamily Housing                2.4
# 1130                           Other                2.3
# 1132                           Other                2.2
# 131                     Fire Station                2.1
# 79              Energy/Power Station                  2
# 1122                           Other                  2
# 567              Multifamily Housing                1.5
# 848                    Not Available                1.4
# 978                           Office                0.9
# 1233                         Parking                0.9
# 833       Non-Refrigerated Warehouse                0.8
# 760              Multifamily Housing                0.3
# 1219                 Other - Stadium                0.3
# 1334           Senior Care Community                0.2
# 1256                  Police Station                0.1
# 1041                          Office                0.1
# 1380                             NaN                NaN
# 1381                             NaN                NaN
# 1382                             NaN                NaN
# 1383                             NaN                NaN
# 1384                             NaN                NaN
#
# [1271 rows x 2 columns]

# %%
# Normally, EUI will not be over 800, which can be proved by this
type_eui_2015[type_eui_2015["Property Type"] == "Senior Care Community"].sort_values(by='Site EUI (kBTU/sf)',ascending=False)
# Out:
#               Property Type Site EUI (kBTU/sf)
# 1339  Senior Care Community                921
# 1336  Senior Care Community              137.3
# 1338  Senior Care Community              136.1
# 1337  Senior Care Community              126.6
# 1335  Senior Care Community               84.4
# 1332  Senior Care Community               81.7
# 1334  Senior Care Community                0.2

# %%
# Detect and remove outliers
to_drop = []
for key,value in type_eui_2015.iterrows():
    if value[1]>800:
        to_drop.append(key)
type_eui_2015 = type_eui_2015.drop(to_drop)
type_eui_2015.sort_values(by='Site EUI (kBTU/sf)', ascending=False)
# Out:
#                                    Property Type Site EUI (kBTU/sf)
# 413               Manufacturing/Industrial Plant              684.5
# 1154                                       Other              619.6
# 412               Manufacturing/Industrial Plant              611.9
# 1152                                       Other              603.6
# 1231                                     Parking              585.4
# 348                                   Laboratory              578.7
# 338                                   Laboratory              568.8
# 778                          Multifamily Housing            564.715
# 408               Manufacturing/Industrial Plant              543.7
# 349                                   Laboratory              527.5
# 345                                   Laboratory              487.6
# 1221                             Other - Utility              474.1
# 1215                  Other - Specialty Hospital              473.6
# 339                                   Laboratory                469
# 341                                   Laboratory              455.4
# 372                                   Laboratory              435.5
# 409               Manufacturing/Industrial Plant              424.1
# 1255                              Police Station              421.7
# 1153                                       Other              418.2
# 360                                   Laboratory              416.9
# 1222  Outpatient Rehabilitation/Physical Therapy              415.7
# 431                               Medical Office              413.7
# 1189                     Other - Public Services              402.1
# 351                                   Laboratory                394
# 1151                                       Other              392.8
# 350                                   Laboratory              391.7
# 346                                   Laboratory              386.5
# 146        Hospital (General Medical & Surgical)              380.6
# 347                                   Laboratory              368.4
# 337                                   Laboratory              362.1
# ...                                          ...                ...
# 1234                                     Parking                5.4
# 1227                                     Parking                  5
# 1160                           Other - Education                4.3
# 1237                                     Parking                4.2
# 500                          Multifamily Housing                3.8
# 582                          Multifamily Housing                3.8
# 77                          Energy/Power Station                3.7
# 555                          Multifamily Housing                2.9
# 1326                                Retail Store                2.9
# 461                          Multifamily Housing                2.4
# 1130                                       Other                2.3
# 1132                                       Other                2.2
# 131                                 Fire Station                2.1
# 79                          Energy/Power Station                  2
# 1122                                       Other                  2
# 567                          Multifamily Housing                1.5
# 848                                Not Available                1.4
# 1233                                     Parking                0.9
# 978                                       Office                0.9
# 833                   Non-Refrigerated Warehouse                0.8
# 1219                             Other - Stadium                0.3
# 760                          Multifamily Housing                0.3
# 1334                       Senior Care Community                0.2
# 1256                              Police Station                0.1
# 1041                                      Office                0.1
# 1380                                         NaN                NaN
# 1381                                         NaN                NaN
# 1382                                         NaN                NaN
# 1383                                         NaN                NaN
# 1384                                         NaN                NaN
#
# [1257 rows x 2 columns]

# %% [markdown]
# ### Group by Property Type, and sum up EUI

# %%
eui2015 = type_eui_2015.groupby("Property Type", as_index = False).sum()
eui2015.columns = ['Property_Type','EUI']
eui2015
# Out:
#                                        Property_Type           EUI
# 0                         Ambulatory Surgical Center    173.100000
# 1                              Automobile Dealership     28.700000
# 2                                           Barracks     49.800000
# 3                                 College/University   6561.700000
# 4                                         Courthouse     90.100000
# 5                                Distribution Center    372.700000
# 6                               Energy/Power Station    109.100000
# 7                                   Financial Office    719.400000
# 8                                       Fire Station   5133.400000
# 9                     Fitness Center/Health Club/Gym    533.600000
# 10             Hospital (General Medical & Surgical)   3029.300000
# 11                                             Hotel   4003.100000
# 12                                  Ice/Curling Rink     85.600000
# 13                                      Indoor Arena    560.900000
# 14                                       K-12 School   8593.200000
# 15                                        Laboratory   9957.700000
# 16                                           Library   2638.100000
# 17                    Manufacturing/Industrial Plant   3003.500000
# 18                                    Medical Office   2082.800000
# 19                                Mixed Use Property   1310.000000
# 20                                     Movie Theater     96.500000
# 21                               Multifamily Housing  29930.609951
# 22                                            Museum    478.600000
# 23                        Non-Refrigerated Warehouse    300.300000
# 24                                     Not Available    294.200000
# 25                                            Office  18717.400000
# 26                                             Other   5277.400000
# 27                                 Other - Education    223.100000
# 28             Other - Entertainment/Public Assembly    306.600000
# 29                       Other - Lodging/Residential   1262.400000
# 30                           Other - Public Services    688.200000
# 31                                Other - Recreation   2609.600000
# 32                        Other - Specialty Hospital    923.100000
# 33                                   Other - Stadium     94.200000
# 34                                   Other - Utility    509.000000
# 35        Outpatient Rehabilitation/Physical Therapy    415.700000
# 36                                           Parking   2118.800000
# 37                                   Performing Arts    266.400000
# 38                                    Police Station   3561.800000
# 39                                        Race Track     43.000000
# 40                            Refrigerated Warehouse     36.400000
# 41  Repair Services (Vehicle, Shoe, Locksmith, etc.)   1240.200000
# 42                          Residence Hall/Dormitory   2476.800000
# 43                                        Restaurant    184.800000
# 44                                      Retail Store    799.800000
# 45                             Self-Storage Facility     59.000000
# 46                             Senior Care Community    566.300000
# 47                                Single Family Home     87.600000
# 48                               Social/Meeting Hall    300.500000
# 49                                    Stadium (Open)    134.700000
# 50                                        Strip Mall     53.800000
# 51                         Supermarket/Grocery Store   3112.900000
# 52               Urgent Care/Clinic/Other Outpatient    222.600000
# 53                        Wholesale Club/Supercenter    167.600000
# 54                                  Worship Facility    195.400000

# %% [markdown]
# # Find common property types

# %%
types2017 = []
for row in eui2017.itertuples():
    if row.Property_Type not in types2017:
        types2017.append(row.Property_Type)

# %%
types2016 = []
for row in eui2016.itertuples():
    if row.Property_Type not in types2016:
        types2016.append(row.Property_Type)

# %%
types2015 = []
for row in eui2015.itertuples():
    if row.Property_Type not in types2015:
        types2015.append(row.Property_Type)

# %%
common = []
for types in types2017:
    if types in types2016 and types in types2015:
        common.append(types)
print("The number of common property types is {}.".format(len(common)))
# Out:
# The number of common property types is 47.

# %% [markdown]
# # Plot how EUI varies with year for main Property Types

# %%
def show(type):
    tmp = {"eui":[]}
    for row in eui2017.itertuples():
        if row.Property_Type == type:
            tmp['eui'].append(row.EUI)
    for row in eui2016.itertuples():
        if row.Property_Type == type:
            tmp['eui'].append(row.EUI)
    for row in eui2015.itertuples():
        if row.Property_Type == type:
            tmp['eui'].append(row.EUI)
    tmp = pd.DataFrame(tmp)
    tmp.index=[2015,2016,2017]
    tmp.plot(kind = "bar",figsize=(8,4),title= "EUI of {} in 2015 - 2017".format(type),color ="black")

# %% [markdown]
# ### Laboratory

# %%
show("Laboratory")

# %% [markdown]
# ### College/University

# %%
show("College/University")

# %% [markdown]
# ### Library

# %%
show("Library")

# %% [markdown]
# ### Hotel

# %%
show("Hotel")

# %% [markdown]
# ### Hospital (General Medical & Surgical)

# %%
show("Hospital (General Medical & Surgical)")

# %% [markdown]
# ### Energy/Power Station

# %%
show("Energy/Power Station")

# %% [markdown]
# ### Supermarket/Grocery Store

# %%
show("Supermarket/Grocery Store")

# %% [markdown]
# ### Residence Hall/Dormitory

# %%
show("Residence Hall/Dormitory")
