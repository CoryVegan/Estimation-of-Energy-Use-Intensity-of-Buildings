# %% [markdown]
# # Average EUI for each property type 2017
#
# Only used berdo to do this job.
#
# 1.property assessment have much more useless information than needed.
#
# 2.the integrated form, too.

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
berdo = pd.read_csv("berdo2017.csv",encoding='latin-1')
#pa = pd.read_csv("property-assessment-fy2017.csv",encoding='latin-1')
#berdo_pa = pd.read_csv("together.csv",encoding='latin-1')

# %%
type_eui = berdo.loc[:,["Property Type","Site EUI (kBTU/sf)"]]
before = len(type_eui)
type_eui = type_eui[type_eui["Site EUI (kBTU/sf)"]!="Not Available"]
after = len(type_eui)
print("Buildings with unavailable Site EUI have been removed . \nThe total number of building data reduced from {} to {}.".format(before,after))
type_eui
# Out:
# Buildings with unavailable Site EUI have been removed .
# The total number of building data reduced from 1800 to 1664.
#                               Property Type Site EUI (kBTU/sf)
# 2                       Multifamily Housing               42.6
# 3                       Multifamily Housing               56.8
# 4                                    Office               26.3
# 5                                   Parking                5.1
# 6                                    Office               98.2
# 7                                    Office                 69
# 8                                     Hotel               86.6
# 10                 Residence Hall/Dormitory               90.2
# 11                                   Office                 63
# 12                                   Office               85.5
# 13                                   Office               64.5
# 14                                   Office               74.2
# ...

# %%
# change the type of Site EUI to float
for i in range(len(type_eui)):
    type_eui.iloc[i][1] = float(type_eui.iloc[i][1])

# %%
type_eui_count = type_eui.copy()
type_eui_count["count"] = np.ones(len(type_eui),dtype=int)

# %%
# The top most property types
count = type_eui_count.groupby("Property Type").sum()
count.sort_values(by="count",ascending=False)
# Out:
#                                                   count
# Property Type
# Multifamily Housing                                 548
# Office                                              297
# K-12 School                                         142
# College/University                                   72
# Hotel                                                47
# Mixed Use Property                                   45
# Residence Hall/Dormitory                             40
# Fire Station                                         40
# Laboratory                                           34
# Library                                              27
# Other                                                25
# Police Station                                       22
# Other - Lodging/Residential                          22
# Medical Office                                       21
# Repair Services (Vehicle, Shoe, Locksmith, etc.)     17
# ...

# %%
type_eui.sort_values(by='Site EUI (kBTU/sf)',ascending=False)
# Out:
#                               Property Type Site EUI (kBTU/sf)
# 501                         Performing Arts        2.73272e+07
# 942     Urgent Care/Clinic/Other Outpatient             417781
# 493                        Worship Facility            63284.2
# 47                                    Hotel              44727
# 1658                                 Museum            31779.9
# 1794                             Strip Mall            21666.5
# 37                                    Other             7753.3
# 1001                    Multifamily Housing             2897.8
# 1056                  Senior Care Community               1824
# 81                      Multifamily Housing             1164.4
# 1329         Manufacturing/Industrial Plant              937.5
# 898                     Multifamily Housing              760.1
# 1460                         Police Station              664.5
# 1714                                  Other              639.4
# ...

# %%
# According to the above form,drop those outliers with a EUI greater than 800
to_drop = []
for key,value in type_eui.iterrows():
    if value[1]>800:
        to_drop.append(key)
type_eui = type_eui.drop(to_drop)
try:type_eui = type_eui.drop([1521])
except:pass
type_eui.sort_values(by='Site EUI (kBTU/sf)', ascending=False)
# Out:
#                                    Property Type Site EUI (kBTU/sf)
# 898                          Multifamily Housing              760.1
# 1460                              Police Station              664.5
# 1714                                       Other              639.4
# 1050              Manufacturing/Industrial Plant              626.1
# 275                                   Laboratory              559.7
# 1635                                       Other              547.2
# 439                          Multifamily Housing              520.3
# 426        Hospital (General Medical & Surgical)              486.9
# 365                   Other - Specialty Hospital                484
# 1782                                      Office                472
# 137                                       Office              463.5
# 386                                   Laboratory              451.8
# 1049                              Police Station              440.7
# ...

# %%
eui = type_eui.groupby("Property Type").sum()
eui_count = eui.merge(count,left_index=True,right_index=True)
ave_eui =[]
for key,value in eui_count.iterrows():
    tmp = value[0]/value[1]
    ave_eui.append(tmp)
type_ave_eui = eui_count.copy()
type_ave_eui["ave_eui"] = ave_eui
type_ave_eui = type_ave_eui.loc[:,["ave_eui"]]
type_ave_eui = type_ave_eui.sort_values(by='ave_eui', ascending=False)
type_ave_eui
# Out:
#                                                      ave_eui
# Property Type
# Laboratory                                        291.385294
# Supermarket/Grocery Store                         262.393750
# Hospital (General Medical & Surgical)             255.321429
# Veterinary Office                                 250.100000
# Swimming Pool                                     237.120000
# Outpatient Rehabilitation/Physical Therapy        217.900000
# Ambulatory Surgical Center                        205.900000
# Other - Specialty Hospital                        203.700000
# Medical Office                                    195.704762
# Police Station                                    171.695455
# Other - Services                                  168.400000
# Other                                             158.936000
# Indoor Arena                                      150.325000
# Fitness Center/Health Club/Gym                    145.975000
# ...

# %%
type_ave_eui.plot.bar(figsize=(18,5),title="Average EUI for each property type")

# %% [markdown]
# # Average EUI for Main Types

# %%
threshold = 10
# determine the drop list
t = count[count["count"]<threshold]
drop_list = list(t.index)
count_dropped = count.drop(drop_list)
print("length of drop list is ",len(drop_list))

# drop those types with less than x buildings in total
type_eui_dropped = type_eui.copy()
for drop in drop_list:
    tmp1 = list(type_eui_count[type_eui_count["Property Type"] == drop].index)
    try:
        type_eui_dropped = type_eui.drop(tmp1)
    except:
        print("error with dropping ",drop)
# Out:
# length of drop list is  38
# error with dropping  Museum
# error with dropping  Other - Utility
# error with dropping  Performing Arts
# error with dropping  Strip Mall
# error with dropping  Urgent Care/Clinic/Other Outpatient

# %%
eui = type_eui_dropped.groupby("Property Type").sum()
eui_count = eui.merge(count_dropped,left_index=True,right_index=True)
ave_eui =[]
for key,value in eui_count.iterrows():
    tmp = value[0]/value[1]
    ave_eui.append(tmp)
type_ave_eui = eui_count.copy()
type_ave_eui["ave_eui"] = ave_eui
type_ave_eui = type_ave_eui.loc[:,["ave_eui"]]
type_ave_eui = type_ave_eui.sort_values(by='ave_eui', ascending=False)
type_ave_eui
# Out:
#                                                      ave_eui
# Property Type
# Laboratory                                        291.385294
# Supermarket/Grocery Store                         262.393750
# Hospital (General Medical & Surgical)             255.321429
# Medical Office                                    195.704762
# Police Station                                    171.695455
# Other                                             158.936000
# Manufacturing/Industrial Plant                    112.968750
# Fire Station                                      111.570000
# Senior Care Community                             107.887500
# Hotel                                             101.478723
# College/University                                 98.954167
# Social/Meeting Hall                                92.964706
# Library                                            84.625926
# Mixed Use Property                                 80.222222
# ...

# %%
type_ave_eui.plot.bar(figsize=(15,5),title="Average EUI for Major Types",fontsize=15)
