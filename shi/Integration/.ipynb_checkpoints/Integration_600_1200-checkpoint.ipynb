# %%
import pandas as pd

# %%
all_berdo = pd.read_csv("berdo2017.csv",encoding='latin-1')
all_pa = pd.read_csv("property-assessment-fy2017.csv",encoding='latin-1')
# Out:
# C:\Users\JialiangShi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (60,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
all_pa.head()
# Out:
#            PID CM_ID       GIS_ID     ST_NUM    ST_NAME ST_NAME_SUF UNIT_NUM  \
# 0  0100001000_   NaN  0100001000_  104 A 104     PUTNAM          ST      NaN
# 1  0100002000_   NaN  0100002000_        197  LEXINGTON          ST      NaN
# 2  0100003000_   NaN  0100003000_        199  LEXINGTON          ST      NaN
# 3  0100004000_   NaN  0100004000_        201  LEXINGTON          ST      NaN
# 4  0100005000_   NaN  0100005000_        203  LEXINGTON          ST      NaN
#
#   ZIPCODE  PTYPE  LU   ...   U_BTH_STYLE2 U_BTH_STYLE3 U_KITCH_TYPE  \
# 0  02128_    105  R3   ...            NaN          NaN          NaN
# 1  02128_    105  R3   ...            NaN          NaN          NaN
# 2  02128_    105  R3   ...            NaN          NaN          NaN
# 3  02128_    105  R3   ...            NaN          NaN          NaN
# 4  02128_    104  R2   ...            NaN          NaN          NaN
#
#   U_KITCH_STYLE U_HEAT_TYP U_AC  U_FPLACE  U_INT_FIN  U_INT_CND  U_VIEW
# ...

# %%
# pa
# leave only what we care
pa = all_pa[["ST_NUM","ST_NAME","ST_NAME_SUF","ZIPCODE","MAIL_ADDRESS","MAIL CS","MAIL_ZIPCODE","YR_BUILT","YR_REMOD","NUM_FLOORS","STRUCTURE_CLASS","R_EXT_FIN","R_HEAT_TYP","U_ORIENT"]]
pa.head()
# Out:
#       ST_NUM    ST_NAME ST_NAME_SUF ZIPCODE      MAIL_ADDRESS         MAIL CS  \
# 0  104 A 104     PUTNAM          ST  02128_  195 LEXINGTON ST  EAST BOSTON MA
# 1        197  LEXINGTON          ST  02128_  197 LEXINGTON ST  EAST BOSTON MA
# 2        199  LEXINGTON          ST  02128_  199 LEXINGTON ST  EAST BOSTON MA
# 3        201  LEXINGTON          ST  02128_      PO BOX 557 #      EVERETT MA
# 4        203  LEXINGTON          ST  02128_  203 LEXINGTON ST  EAST BOSTON MA
#
#   MAIL_ZIPCODE  YR_BUILT  YR_REMOD  NUM_FLOORS STRUCTURE_CLASS R_EXT_FIN  \
# 0       02128_    1900.0       NaN         3.0               R         A
# 1       02128_    1920.0    2000.0         3.0               R         M
# 2       02128_    1905.0    1985.0         3.0               R         M
# 3       02149_    1900.0    1991.0         3.0               R         M
# 4       02128_    1900.0    1978.0         3.0               R         M
#
#   R_HEAT_TYP U_ORIENT
# 0          W      NaN
# ...

# %%
# pa
# add one more coloum of the line number
tmp=[]
for line in pa.iterrows():
   tmp.append(line[0])
pa["dy"]=tmp
pa.head()
# Out:
# C:\Users\JialiangShi\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#       ST_NUM    ST_NAME ST_NAME_SUF ZIPCODE      MAIL_ADDRESS         MAIL CS  \
# 0  104 A 104     PUTNAM          ST  02128_  195 LEXINGTON ST  EAST BOSTON MA
# 1        197  LEXINGTON          ST  02128_  197 LEXINGTON ST  EAST BOSTON MA
# 2        199  LEXINGTON          ST  02128_  199 LEXINGTON ST  EAST BOSTON MA
# 3        201  LEXINGTON          ST  02128_      PO BOX 557 #      EVERETT MA
# 4        203  LEXINGTON          ST  02128_  203 LEXINGTON ST  EAST BOSTON MA
#
#   MAIL_ZIPCODE  YR_BUILT  YR_REMOD  NUM_FLOORS STRUCTURE_CLASS R_EXT_FIN  \
# 0       02128_    1900.0       NaN         3.0               R         A
# ...

# %%
# berdo
# leave only what we care
berdo = all_berdo.iloc[:,[0,2,3,4,6,10,11,12,13,14,15,]].loc[601:1200]
berdo
# Out:
#                                    Property Name  \
# 601                         Traveler Storage LLC
# 602                  Gateway Terrace Condominium
# 603                           Northampton Campus
# 604                                   Womens Inn
# 605                                   BLACKSTONE
# 606                                       CARTER
# 607                 Central Maintenance Facility
# 608                     434 Massachusetts Avenue
# 609                                46 Waltham St
# 610                             580 Harrison Ave
# 611           James Court: 45 East Newton Street
# 612                             450 Harrison Ave
# 613                             460 Harrison Ave
# 614                                 Jordan Lofts
# 615                   Harrison Lofts Condo Trust
# 616                          Beck Southend Trust
# 617                       Boston Flower Exchange
# 618              Robert Fortes: 541 Shawmut Ave.
# ...

# %%
# berdo
# search all properties with xxx in the Property Name
tmp1 = [ "Arborway"in berdo["Address"].iloc[i]  for i in range(len(berdo))]
berdo1 = berdo.copy()
berdo1["tmp"] = tmp1
berdo1 = berdo1[berdo1["tmp"]==True]
berdo1
# Out:
#                      Property Name        Property Type  \
# 1199  Arborway Gardens Condominium  Multifamily Housing
#
#                                       Address    ZIP Site EUI (kBTU/sf)  \
# 1199  461, 463, 467, 469, 493, 495 Arborway,   02130               95.6
#
#       Year Built  GHG Emissions (MTCO2e)  GHG Intensity (kgCO2/sf)  \
# 1199        1950                   805.7                       5.4
#
#       Total Site Energy (kBTU)  % Electricity  % Gas   tmp
# 1199              14,362,514.5           9.2%  90.8%  True

# %%
# pa
# search all properties with number n in the ST_NUM
_ = pa[pa["ST_NAME"]=="Arborway".upper()]
tmp = [ str(n).upper() in _["ST_NUM"].iloc[i] for i in range(len(_))]
_["tmp"] = tmp
__ = _[_["tmp"]==True]
__
# Out:
# C:\Users\JialiangShi\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#         ST_NUM   ST_NAME ST_NAME_SUF ZIPCODE          MAIL_ADDRESS  \
# 82214  461 495  ARBORWAY          ST  02130_         PO BOX 600344
# 82215  461 495  ARBORWAY          ST  02130_         PO BOX 600344
# 82216  461 495  ARBORWAY          ST  02130_         PO BOX 600344
# 82217  461 495  ARBORWAY          ST  02130_         PO BOX 600344
# 82218  461 495  ARBORWAY          ST  02130_         PO BOX 600344
# 82219  461 495  ARBORWAY          ST  02130_         PO BOX 600344
# 82220  461 495  ARBORWAY          ST  02130_         PO BOX 600344
# ...

# %%
# pa
# search all properties with xxxx in the MAIL_ADDRESS
s = "Lakville"
tmp = [ s.upper() in pa["MAIL_ADDRESS"].iloc[i] and "#" not in pa["MAIL_ADDRESS"][i] for i in range(len(pa))]
#tmp = [ s.upper() in pa["MAIL_ADDRESS"].iloc[i] for i in range(len(pa))]
pa["tmp"] = tmp
_ = pa[pa["tmp"]==True]
_
# Out:
# C:\Users\JialiangShi\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# Empty DataFrame
# Columns: [ST_NUM, ST_NAME, ST_NAME_SUF, ZIPCODE, MAIL_ADDRESS, MAIL CS, MAIL_ZIPCODE, YR_BUILT, YR_REMOD, NUM_FLOORS, STRUCTURE_CLASS, R_EXT_FIN, R_HEAT_TYP, U_ORIENT, tmp]
# Index: []

# %%
dy = pd.read_csv("dy1.csv",encoding='latin-1')

# %%
dy
# Out:
#          dy
# 0     30040
# 1     29017
# 2     70764
# 3     30031
# 4        -1
# 5        -1
# 6     69150
# 7     84785
# 8        -1
# 9     29965
# 10    69867
# 11    30010
# 12       -1
# 13    29438
# 14    29439
# 15    69349
# 16    69220
# 17    73497
# 18    69372
# 19       -1
# 20    73873
# 21    73773
# 22    69588
# 23    69189
# 24       -1
# 25       -1
# 26    73848
# 27    69374
# 28    73962
# 29       -1
# ..      ...
# 570      -1
# 571      -1
# 572   83053
# 573  162416
# 574   77520
# 575      -1
# 576   83478
# 577   77461
# 578   82809
# 579  138102
# 580   76926
# 581      -1
# 582   80323
# 583   80583
# 584   77712
# 585   81163
# 586      -1
# 587      -1
# 588   82805
# 589   82802
# 590  134211
# 591   78287
# 592   77993
# 593      -1
# 594   77199
# 595  135029
# 596  134418
# 597  143014
# 598   82221
# 599   80600
#
# [600 rows x 1 columns]

# %%
for i in range(600):
    tmp = dy.index[i]
    dy = dy.rename(index={tmp: str(i+601)})
dy
# Out:
#           dy
# 601    30040
# 602    29017
# 603    70764
# 604    30031
# 605       -1
# 606       -1
# 607    69150
# 608    84785
# 609       -1
# 610    29965
# 611    69867
# 612    30010
# 613       -1
# 614    29438
# 615    29439
# 616    69349
# 617    69220
# 618    73497
# 619    69372
# 620       -1
# 621    73873
# 622    73773
# 623    69588
# 624    69189
# 625       -1
# 626       -1
# 627    73848
# 628    69374
# 629    73962
# 630       -1
# ...      ...
# 1171      -1
# 1172      -1
# 1173   83053
# 1174  162416
# 1175   77520
# 1176      -1
# 1177   83478
# 1178   77461
# 1179   82809
# 1180  138102
# 1181   76926
# 1182      -1
# 1183   80323
# 1184   80583
# 1185   77712
# 1186   81163
# 1187      -1
# 1188      -1
# 1189   82805
# 1190   82802
# 1191  134211
# 1192   78287
# 1193   77993
# 1194      -1
# 1195   77199
# 1196  135029
# 1197  134418
# 1198  143014
# 1199   82221
# 1200   80600
#
# [600 rows x 1 columns]

# %%
tmp = []
for line in dy.iterrows():
    #print(line[1][0])
    tmp.append(line[1][0])
berdo["dy"] = tmp
berdo
# Out:
#                                    Property Name  \
# 601                         Traveler Storage LLC
# 602                  Gateway Terrace Condominium
# 603                           Northampton Campus
# 604                                   Womens Inn
# 605                                   BLACKSTONE
# 606                                       CARTER
# 607                 Central Maintenance Facility
# 608                     434 Massachusetts Avenue
# 609                                46 Waltham St
# 610                             580 Harrison Ave
# 611           James Court: 45 East Newton Street
# 612                             450 Harrison Ave
# 613                             460 Harrison Ave
# 614                                 Jordan Lofts
# 615                   Harrison Lofts Condo Trust
# 616                          Beck Southend Trust
# 617                       Boston Flower Exchange
# 618              Robert Fortes: 541 Shawmut Ave.
# ...

# %%
berdo_3 = berdo[["Address","ZIP","Site EUI (kBTU/sf)","dy"]]
berdo_3
# Out:
#                                                 Address    ZIP  \
# 601                                  33 Traveler Street  02118
# 602   35 Fay Street, 40 Fay Street, 1166 Washington ...  02118
# 603                               35 Northampton Street  02118
# 604                                  363 Albany Street   02118
# 605                                    380 Shawmut Ave.  02118
# 606                                 396 Northampton St.  02118
# 607                                     400 Frontage Rd  02118
# 608                            434 Massachusetts Avenue  02118
# 609                                       44 Waltham St  02118
# 610                                       443 Albany St  02118
# 611                               45 East Newton Street  02118
# 612                                    450 Harrison Ave  02118
# 613                                    460 Harrison Ave  02118
# 614                                 477 Harrison Avenue  02118
# ...

# %%
all = pd.merge(all_pa,berdo_3,on="dy")
all = all.drop(["dy"], axis=1)
all
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dy'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-7fd4a8b08ac2> in <module>()
# ----> 1 all = pd.merge(all_pa,berdo_3,on="dy")
# ...

# %%
all.to_csv('601-1200.csv')
