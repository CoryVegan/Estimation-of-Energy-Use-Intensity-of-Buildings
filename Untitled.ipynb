# %%
import pandas as pd

# %%
df = pd.read_csv("berdo2017.csv",encoding='latin-1')

# %%
df
# Out:
#                                          Property Name    Reported  \
# 0                                              Harpoon         Yes
# 1                                    SMFA Mission Hill         Yes
# 2                              Commonwealth Apartments         Yes
# 3                              River House Condo Trust         Yes
# 4                                 44 School Street LLC         Yes
# 5                                      10 Necco Street         Yes
# 6                                           One Beacon         Yes
# 7                                         Center Plaza         Yes
# 8                                           Ames Hotel         Yes
# 9                                  One Washington Mall         Yes
# 10                                         Miller Hall         Yes
# 11                                   10 Tremont Street         Yes
# 12                             Sears Crescent Building         Yes
# ...
